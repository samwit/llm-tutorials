# %%
# !pip -q install transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 48.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 82.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 16.3 MB/s eta 0:00:00

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "cerebras/Cerebras-GPT-6.7B"
# model_name = "cerebras/Cerebras-GPT-2.7B"
# model_name = "cerebras/Cerebras-GPT-13B"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/361 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/26.8G [00:00<?, ?B/s]

# %%
from transformers import pipeline

text = "Generative AI is "

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)

generated_text = pipe(text, 
                      max_length=50, 
                      do_sample=False, 
                      no_repeat_ngram_size=2)[0]

                      
print(generated_text['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generative AI is
#    *  a process of creating a model of the world that can be used to  generate  new  data  and  make  predictions.  The  model  is a  representation  of  the

# %%
from transformers import GenerationConfig

text = "Unicorns can be found "

inputs = tokenizer(text, return_tensors="pt")

generation_config = GenerationConfig(
        temperature=0.6,
        top_p=0.95,
        repetition_penalty=1.2,
    )

outputs = model.generate(**inputs, #the tokens
                        num_beams=5, 
                        max_new_tokens=150, 
                        early_stopping=True,
                        generation_config=generation_config,
                        no_repeat_ngram_size=2)

text_output = tokenizer.batch_decode(outputs, skip_special_tokens=True)

print(text_output[0])
# Out:
# Unicorns can be found
# in the forests of the world.
#
# The unicorn is a mythical creature with a horn on its head and a hoof in its foot. It is said to have been born from the tears of a weeping unicorn. The unicorn's horn is believed to be magical, and it is often used as a talisman to ward off evil spirits and to protect the wearer from harm. In the Middle Ages, the unicorn was a symbol of purity and chastity, but in modern times, it has come to symbolize strength and courage, as well as good fortune and good health. Unicorns are often depicted in art as beautiful, graceful creatures with long, flowing manes and tails. They are usually shown with their heads turned toward the viewer

# %%
PROMPT = """Below is an instruction that describes a task. Write a response that appropriately completes the request.
### Instruction:
What are the differences between alpacas and sheep?
### Response:"""

generated_text = pipe(PROMPT, 
                      max_length=50, 
                      do_sample=False, 
                      no_repeat_ngram_size=2)[0]

                      
print(generated_text['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
# ### Instruction:
# What are the differences between alpacas and sheep?
# ### Response:
#
#   1.
#   2. Alpac

# %%
PROMPT = """the differences between alpacas and sheep are"""

generated_text = pipe(PROMPT, 
                      max_length=150, 
                      do_sample=False, 
                      no_repeat_ngram_size=2)[0]

                      
print(generated_text['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# the differences between alpacas and sheep are not as great as between sheep and goats, and the differences are less pronounced than between goats and cattle.
#
# The alpaca is a member of the camelid family, which includes the dromedary, llama, alpine ibex, African wild ass, Arabian oryx, dama gazelle, gerenuk, klipspringer, nyala, oribi, orangutans, pangolin, red panda, sable antelope, silver pheasant, rock hyrax, springbok, steenbock, tsessebe, waterbuck, wildebeest, zebra, giraffe, harte
